# %% [markdown]
# <a href="https://colab.research.google.com/github/irohit373/langchain-experiments/blob/main/QuickStart_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qU langchain-community tiktoken matplotlib seaborn tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 36.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.6 MB/s eta 0:00:00

# %%
# !wget -r -A.html -P rtdocs https://getbootstrap.com/docs/4.1/
# Out:
# Streaming output truncated to the last 5000 lines.
# 2025-04-16 19:13:42 (239 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/migration/index.html’ saved [68934]
#
# --2025-04-16 19:13:42--  https://getbootstrap.com/docs/4.0/about/overview/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/about/overview/index.html’
#
# getbootstrap.com/do     [ <=>                ]  20.76K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:42 (254 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/about/overview/index.html’ saved [21263]
#
# --2025-04-16 19:13:42--  https://getbootstrap.com/docs/4.0/about/brand/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/about/brand/index.html’
#
# getbootstrap.com/do     [ <=>                ]  21.66K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:42 (270 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/about/brand/index.html’ saved [22176]
#
# --2025-04-16 19:13:42--  https://getbootstrap.com/docs/4.0/about/license/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/about/license/index.html’
#
# getbootstrap.com/do     [ <=>                ]  20.12K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:43 (251 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/about/license/index.html’ saved [20605]
#
# --2025-04-16 19:13:43--  https://getbootstrap.com/docs/4.0/about/translations/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/about/translations/index.html’
#
# getbootstrap.com/do     [ <=>                ]  19.03K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:43 (240 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/about/translations/index.html’ saved [19489]
#
# --2025-04-16 19:13:43--  https://getbootstrap.com/docs/3.3/examples/starter-template/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/starter-template/index.html’
#
# getbootstrap.com/do     [ <=>                ]   3.27K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:43 (471 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/starter-template/index.html’ saved [3347]
#
# --2025-04-16 19:13:43--  https://getbootstrap.com/docs/3.3/examples/theme/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/theme/index.html’
#
# getbootstrap.com/do     [ <=>                ]  25.98K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:43 (156 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/theme/index.html’ saved [26605]
#
# --2025-04-16 19:13:43--  https://getbootstrap.com/docs/3.3/examples/grid/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/grid/index.html’
#
# getbootstrap.com/do     [ <=>                ]   6.57K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:43 (1022 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/grid/index.html’ saved [6731]
#
# --2025-04-16 19:13:43--  https://getbootstrap.com/docs/3.3/examples/jumbotron/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/jumbotron/index.html’
#
# getbootstrap.com/do     [ <=>                ]   5.10K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:43 (734 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/jumbotron/index.html’ saved [5219]
#
# --2025-04-16 19:13:43--  https://getbootstrap.com/docs/3.3/examples/jumbotron-narrow/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/jumbotron-narrow/index.html’
#
# getbootstrap.com/do     [ <=>                ]   3.50K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:43 (672 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/jumbotron-narrow/index.html’ saved [3580]
#
# --2025-04-16 19:13:43--  https://getbootstrap.com/docs/3.3/examples/navbar/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/navbar/index.html’
#
# getbootstrap.com/do     [ <=>                ]   4.57K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:44 (867 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/navbar/index.html’ saved [4681]
#
# --2025-04-16 19:13:44--  https://getbootstrap.com/docs/3.3/examples/navbar-static-top/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/navbar-static-top/index.html’
#
# getbootstrap.com/do     [ <=>                ]   4.60K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:44 (796 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/navbar-static-top/index.html’ saved [4707]
#
# --2025-04-16 19:13:44--  https://getbootstrap.com/docs/3.3/examples/navbar-fixed-top/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/navbar-fixed-top/index.html’
#
# getbootstrap.com/do     [ <=>                ]   4.59K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:44 (1000 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/navbar-fixed-top/index.html’ saved [4702]
#
# --2025-04-16 19:13:44--  https://getbootstrap.com/docs/3.3/examples/cover/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/cover/index.html’
#
# getbootstrap.com/do     [ <=>                ]   3.30K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:44 (864 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/cover/index.html’ saved [3378]
#
# --2025-04-16 19:13:44--  https://getbootstrap.com/docs/3.3/examples/carousel/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/carousel/index.html’
#
# getbootstrap.com/do     [ <=>                ]  11.33K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:44 (261 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/carousel/index.html’ saved [11603]
#
# --2025-04-16 19:13:44--  https://getbootstrap.com/docs/3.3/examples/blog/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/blog/index.html’
#
# getbootstrap.com/do     [ <=>                ]   9.71K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:44 (226 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/blog/index.html’ saved [9939]
#
# --2025-04-16 19:13:44--  https://getbootstrap.com/docs/3.3/examples/dashboard/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/dashboard/index.html’
#
# getbootstrap.com/do     [ <=>                ]   9.54K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:44 (213 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/dashboard/index.html’ saved [9765]
#
# --2025-04-16 19:13:44--  https://getbootstrap.com/docs/3.3/examples/signin/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/signin/index.html’
#
# getbootstrap.com/do     [ <=>                ]   2.39K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:45 (152 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/signin/index.html’ saved [2447]
#
# --2025-04-16 19:13:45--  https://getbootstrap.com/docs/3.3/examples/justified-nav/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/justified-nav/index.html’
#
# getbootstrap.com/do     [ <=>                ]   4.31K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:45 (815 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/justified-nav/index.html’ saved [4418]
#
# --2025-04-16 19:13:45--  https://getbootstrap.com/docs/3.3/examples/sticky-footer/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/sticky-footer/index.html’
#
# getbootstrap.com/do     [ <=>                ]   2.20K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:45 (418 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/sticky-footer/index.html’ saved [2251]
#
# --2025-04-16 19:13:45--  https://getbootstrap.com/docs/3.3/examples/sticky-footer-navbar/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/sticky-footer-navbar/index.html’
#
# getbootstrap.com/do     [ <=>                ]   4.33K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:45 (742 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/sticky-footer-navbar/index.html’ saved [4430]
#
# --2025-04-16 19:13:45--  https://getbootstrap.com/docs/3.3/examples/non-responsive/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/non-responsive/index.html’
#
# getbootstrap.com/do     [ <=>                ]   5.82K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:45 (929 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/non-responsive/index.html’ saved [5960]
#
# --2025-04-16 19:13:45--  https://getbootstrap.com/docs/3.3/examples/offcanvas/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/examples/offcanvas/index.html’
#
# getbootstrap.com/do     [ <=>                ]   7.28K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:45 (1.25 GB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/examples/offcanvas/index.html’ saved [7452]
#
# --2025-04-16 19:13:45--  https://getbootstrap.com/docs/3.3/migration/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/migration/index.html’
#
# getbootstrap.com/do     [ <=>                ]  17.62K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:45 (121 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/migration/index.html’ saved [18040]
#
# --2025-04-16 19:13:45--  https://getbootstrap.com/docs/3.3/browser-bugs/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/3.3/browser-bugs/index.html’
#
# getbootstrap.com/do     [ <=>                ]  26.51K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:46 (184 MB/s) - ‘rtdocs/getbootstrap.com/docs/3.3/browser-bugs/index.html’ saved [27144]
#
# --2025-04-16 19:13:46--  https://getbootstrap.com/getting-started/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/getting-started/index.html’
#
# getbootstrap.com/ge     [ <=>                ]     498  --.-KB/s    in 0s
#
# 2025-04-16 19:13:46 (134 MB/s) - ‘rtdocs/getbootstrap.com/getting-started/index.html’ saved [498]
#
# --2025-04-16 19:13:46--  https://getbootstrap.com/2.3.2/examples/starter-template.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/2.3.2/examples/starter-template.html’
#
# getbootstrap.com/2.     [ <=>                ]   3.25K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:46 (710 MB/s) - ‘rtdocs/getbootstrap.com/2.3.2/examples/starter-template.html’ saved [3333]
#
# --2025-04-16 19:13:46--  https://getbootstrap.com/2.3.2/examples/hero.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/2.3.2/examples/hero.html’
#
# getbootstrap.com/2.     [ <=>                ]   5.69K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:46 (1.39 GB/s) - ‘rtdocs/getbootstrap.com/2.3.2/examples/hero.html’ saved [5825]
#
# --2025-04-16 19:13:46--  https://getbootstrap.com/2.3.2/examples/fluid.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/2.3.2/examples/fluid.html’
#
# getbootstrap.com/2.     [ <=>                ]   7.52K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:46 (1.54 GB/s) - ‘rtdocs/getbootstrap.com/2.3.2/examples/fluid.html’ saved [7697]
#
# --2025-04-16 19:13:46--  https://getbootstrap.com/2.3.2/examples/marketing-narrow.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/2.3.2/examples/marketing-narrow.html’
#
# getbootstrap.com/2.     [ <=>                ]   4.60K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:46 (1.14 GB/s) - ‘rtdocs/getbootstrap.com/2.3.2/examples/marketing-narrow.html’ saved [4712]
#
# --2025-04-16 19:13:46--  https://getbootstrap.com/2.3.2/examples/justified-nav.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/2.3.2/examples/justified-nav.html’
#
# getbootstrap.com/2.     [ <=>                ]   5.99K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:46 (1.31 GB/s) - ‘rtdocs/getbootstrap.com/2.3.2/examples/justified-nav.html’ saved [6130]
#
# --2025-04-16 19:13:46--  https://getbootstrap.com/2.3.2/examples/signin.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/2.3.2/examples/signin.html’
#
# getbootstrap.com/2.     [ <=>                ]   3.55K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:47 (940 MB/s) - ‘rtdocs/getbootstrap.com/2.3.2/examples/signin.html’ saved [3634]
#
# --2025-04-16 19:13:47--  https://getbootstrap.com/2.3.2/examples/sticky-footer.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/2.3.2/examples/sticky-footer.html’
#
# getbootstrap.com/2.     [ <=>                ]   4.07K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:47 (1.22 GB/s) - ‘rtdocs/getbootstrap.com/2.3.2/examples/sticky-footer.html’ saved [4163]
#
# --2025-04-16 19:13:47--  https://getbootstrap.com/2.3.2/examples/carousel.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/2.3.2/examples/carousel.html’
#
# getbootstrap.com/2.     [ <=>                ]  15.27K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:47 (193 MB/s) - ‘rtdocs/getbootstrap.com/2.3.2/examples/carousel.html’ saved [15636]
#
# --2025-04-16 19:13:47--  https://getbootstrap.com/css/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/css/index.html’
#
# getbootstrap.com/cs     [ <=>                ]     497  --.-KB/s    in 0s
#
# 2025-04-16 19:13:47 (147 MB/s) - ‘rtdocs/getbootstrap.com/css/index.html’ saved [497]
#
# --2025-04-16 19:13:47--  https://getbootstrap.com/components/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/components/index.html’
#
# getbootstrap.com/co     [ <=>                ]     474  --.-KB/s    in 0s
#
# 2025-04-16 19:13:47 (169 MB/s) - ‘rtdocs/getbootstrap.com/components/index.html’ saved [474]
#
# --2025-04-16 19:13:47--  https://getbootstrap.com/javascript/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/javascript/index.html’
#
# getbootstrap.com/ja     [ <=>                ]     525  --.-KB/s    in 0s
#
# 2025-04-16 19:13:47 (208 MB/s) - ‘rtdocs/getbootstrap.com/javascript/index.html’ saved [525]
#
# --2025-04-16 19:13:47--  https://getbootstrap.com/docs/5.2/getting-started/contents/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/getting-started/contents/index.html’
#
# getbootstrap.com/do     [ <=>                ]  63.54K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:47 (248 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/getting-started/contents/index.html’ saved [65066]
#
# --2025-04-16 19:13:47--  https://getbootstrap.com/docs/5.2/getting-started/browsers-devices/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/getting-started/browsers-devices/index.html’
#
# getbootstrap.com/do     [ <=>                ]  62.57K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:48 (271 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/getting-started/browsers-devices/index.html’ saved [64075]
#
# --2025-04-16 19:13:48--  https://getbootstrap.com/docs/5.2/getting-started/accessibility/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/getting-started/accessibility/index.html’
#
# getbootstrap.com/do     [ <=>                ]  62.75K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:48 (230 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/getting-started/accessibility/index.html’ saved [64252]
#
# --2025-04-16 19:13:48--  https://getbootstrap.com/docs/5.2/getting-started/rfs/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/getting-started/rfs/index.html’
#
# getbootstrap.com/do     [ <=>                ]  63.20K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:48 (230 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/getting-started/rfs/index.html’ saved [64721]
#
# --2025-04-16 19:13:48--  https://getbootstrap.com/docs/5.2/getting-started/rtl/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/getting-started/rtl/index.html’
#
# getbootstrap.com/do     [ <=>                ]  74.40K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:48 (235 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/getting-started/rtl/index.html’ saved [76181]
#
# --2025-04-16 19:13:48--  https://getbootstrap.com/docs/5.2/getting-started/contribute/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/getting-started/contribute/index.html’
#
# getbootstrap.com/do     [ <=>                ]  60.98K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:48 (249 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/getting-started/contribute/index.html’ saved [62448]
#
# --2025-04-16 19:13:48--  https://getbootstrap.com/docs/5.2/customize/color/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/customize/color/index.html’
#
# getbootstrap.com/do     [ <=>                ]  77.58K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:48 (272 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/customize/color/index.html’ saved [79447]
#
# --2025-04-16 19:13:48--  https://getbootstrap.com/docs/5.2/customize/components/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/customize/components/index.html’
#
# getbootstrap.com/do     [ <=>                ]  70.95K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:49 (318 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/customize/components/index.html’ saved [72657]
#
# --2025-04-16 19:13:49--  https://getbootstrap.com/docs/5.2/customize/optimize/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/customize/optimize/index.html’
#
# getbootstrap.com/do     [ <=>                ]  70.47K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:49 (265 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/customize/optimize/index.html’ saved [72157]
#
# --2025-04-16 19:13:49--  https://getbootstrap.com/docs/5.2/layout/breakpoints/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/layout/breakpoints/index.html’
#
# getbootstrap.com/do     [ <=>                ]  76.76K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:49 (218 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/layout/breakpoints/index.html’ saved [78602]
#
# --2025-04-16 19:13:49--  https://getbootstrap.com/docs/5.2/layout/containers/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/layout/containers/index.html’
#
# getbootstrap.com/do     [ <=>                ]  65.76K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:49 (251 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/layout/containers/index.html’ saved [67343]
#
# --2025-04-16 19:13:49--  https://getbootstrap.com/docs/5.2/layout/grid/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/layout/grid/index.html’
#
# getbootstrap.com/do     [ <=>                ] 137.99K  --.-KB/s    in 0.004s
#
# 2025-04-16 19:13:49 (31.6 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/layout/grid/index.html’ saved [141301]
#
# --2025-04-16 19:13:49--  https://getbootstrap.com/docs/5.2/layout/columns/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/layout/columns/index.html’
#
# getbootstrap.com/do     [ <=>                ] 117.33K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:49 (118 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/layout/columns/index.html’ saved [120142]
#
# --2025-04-16 19:13:49--  https://getbootstrap.com/docs/5.2/layout/gutters/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/layout/gutters/index.html’
#
# getbootstrap.com/do     [ <=>                ]  87.84K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:49 (205 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/layout/gutters/index.html’ saved [89947]
#
# --2025-04-16 19:13:49--  https://getbootstrap.com/docs/5.2/layout/utilities/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/layout/utilities/index.html’
#
# getbootstrap.com/do     [ <=>                ]  57.31K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:50 (294 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/layout/utilities/index.html’ saved [58686]
#
# --2025-04-16 19:13:50--  https://getbootstrap.com/docs/5.2/layout/z-index/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/layout/z-index/index.html’
#
# getbootstrap.com/do     [ <=>                ]  56.91K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:50 (218 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/layout/z-index/index.html’ saved [58276]
#
# --2025-04-16 19:13:50--  https://getbootstrap.com/docs/5.2/layout/css-grid/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 503 Service Unavailable
# 2025-04-16 19:13:50 ERROR 503: Service Unavailable.
#
# --2025-04-16 19:13:50--  https://getbootstrap.com/docs/5.2/content/reboot/
# Connecting to getbootstrap.com (getbootstrap.com)|104.22.59.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/content/reboot/index.html’
#
# getbootstrap.com/do     [ <=>                ] 103.24K  --.-KB/s    in 0.02s
#
# 2025-04-16 19:13:50 (4.23 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/content/reboot/index.html’ saved [105717]
#
# --2025-04-16 19:13:50--  https://getbootstrap.com/docs/5.2/content/typography/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/content/typography/index.html’
#
# getbootstrap.com/do     [ <=>                ] 113.66K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:50 (110 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/content/typography/index.html’ saved [116392]
#
# --2025-04-16 19:13:50--  https://getbootstrap.com/docs/5.2/content/images/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/content/images/index.html’
#
# getbootstrap.com/do     [ <=>                ]  68.63K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:50 (315 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/content/images/index.html’ saved [70275]
#
# --2025-04-16 19:13:50--  https://getbootstrap.com/docs/5.2/content/tables/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/content/tables/index.html’
#
# getbootstrap.com/do     [ <=>                ] 169.60K  --.-KB/s    in 0.002s
#
# 2025-04-16 19:13:51 (93.9 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/content/tables/index.html’ saved [173671]
#
# --2025-04-16 19:13:51--  https://getbootstrap.com/docs/5.2/content/figures/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/content/figures/index.html’
#
# getbootstrap.com/do     [ <=>                ]  60.73K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:51 (278 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/content/figures/index.html’ saved [62183]
#
# --2025-04-16 19:13:51--  https://getbootstrap.com/docs/5.2/forms/overview/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/forms/overview/index.html’
#
# getbootstrap.com/do     [ <=>                ]  88.30K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:51 (335 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/forms/overview/index.html’ saved [90420]
#
# --2025-04-16 19:13:51--  https://getbootstrap.com/docs/5.2/forms/form-control/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/forms/form-control/index.html’
#
# getbootstrap.com/do     [ <=>                ] 105.19K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:51 (130 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/forms/form-control/index.html’ saved [107719]
#
# --2025-04-16 19:13:51--  https://getbootstrap.com/docs/5.2/forms/select/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/forms/select/index.html’
#
# getbootstrap.com/do     [ <=>                ]  79.92K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:51 (252 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/forms/select/index.html’ saved [81837]
#
# --2025-04-16 19:13:51--  https://getbootstrap.com/docs/5.2/forms/checks-radios/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/forms/checks-radios/index.html’
#
# getbootstrap.com/do     [ <=>                ] 144.30K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:51 (210 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/forms/checks-radios/index.html’ saved [147767]
#
# --2025-04-16 19:13:51--  https://getbootstrap.com/docs/5.2/forms/range/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/forms/range/index.html’
#
# getbootstrap.com/do     [ <=>                ]  68.44K  --.-KB/s    in 0.002s
#
# 2025-04-16 19:13:52 (40.4 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/forms/range/index.html’ saved [70082]
#
# --2025-04-16 19:13:52--  https://getbootstrap.com/docs/5.2/forms/input-group/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/forms/input-group/index.html’
#
# getbootstrap.com/do     [ <=>                ] 150.72K  --.-KB/s    in 0.002s
#
# 2025-04-16 19:13:52 (85.4 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/forms/input-group/index.html’ saved [154334]
#
# --2025-04-16 19:13:52--  https://getbootstrap.com/docs/5.2/forms/floating-labels/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/forms/floating-labels/index.html’
#
# getbootstrap.com/do     [ <=>                ]  93.59K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:52 (103 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/forms/floating-labels/index.html’ saved [95834]
#
# --2025-04-16 19:13:52--  https://getbootstrap.com/docs/5.2/forms/layout/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/forms/layout/index.html’
#
# getbootstrap.com/do     [ <=>                ] 139.86K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:52 (147 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/forms/layout/index.html’ saved [143214]
#
# --2025-04-16 19:13:52--  https://getbootstrap.com/docs/5.2/forms/validation/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/forms/validation/index.html’
#
# getbootstrap.com/do     [ <=>                ] 177.35K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:52 (308 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/forms/validation/index.html’ saved [181607]
#
# --2025-04-16 19:13:52--  https://getbootstrap.com/docs/5.2/components/accordion/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/components/accordion/index.html’
#
# getbootstrap.com/do     [ <=>                ] 114.66K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:52 (151 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/components/accordion/index.html’ saved [117414]
#
# --2025-04-16 19:13:52--  https://getbootstrap.com/docs/5.2/components/badge/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/components/badge/index.html’
#
# getbootstrap.com/do     [ <=>                ]  80.29K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:52 (124 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/components/badge/index.html’ saved [82214]
#
# --2025-04-16 19:13:52--  https://getbootstrap.com/docs/5.2/components/breadcrumb/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/components/breadcrumb/index.html’
#
# getbootstrap.com/do     [ <=>                ]  79.98K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:52 (186 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/components/breadcrumb/index.html’ saved [81904]
#
# --2025-04-16 19:13:52--  https://getbootstrap.com/docs/5.2/components/button-group/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/components/button-group/index.html’
#
# getbootstrap.com/do     [ <=>                ] 134.54K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:53 (160 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/components/button-group/index.html’ saved [137772]
#
# --2025-04-16 19:13:53--  https://getbootstrap.com/docs/5.2/components/card/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/components/card/index.html’
#
# getbootstrap.com/do     [ <=>                ] 281.02K  --.-KB/s    in 0.003s
#
# 2025-04-16 19:13:53 (98.4 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/components/card/index.html’ saved [287760]
#
# --2025-04-16 19:13:53--  https://getbootstrap.com/docs/5.2/components/close-button/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/components/close-button/index.html’
#
# getbootstrap.com/do     [ <=>                ]  63.81K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:53 (115 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/components/close-button/index.html’ saved [65338]
#
# --2025-04-16 19:13:53--  https://getbootstrap.com/docs/5.2/components/list-group/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/components/list-group/index.html’
#
# getbootstrap.com/do     [ <=>                ] 189.07K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:53 (136 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/components/list-group/index.html’ saved [193611]
#
# --2025-04-16 19:13:53--  https://getbootstrap.com/docs/5.2/components/navbar/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/components/navbar/index.html’
#
# getbootstrap.com/do     [ <=>                ] 266.57K  --.-KB/s    in 0.002s
#
# 2025-04-16 19:13:53 (109 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/components/navbar/index.html’ saved [272965]
#
# --2025-04-16 19:13:53--  https://getbootstrap.com/docs/5.2/components/pagination/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/components/pagination/index.html’
#
# getbootstrap.com/do     [ <=>                ] 113.38K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:53 (130 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/components/pagination/index.html’ saved [116104]
#
# --2025-04-16 19:13:53--  https://getbootstrap.com/docs/5.2/components/placeholders/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/components/placeholders/index.html’
#
# getbootstrap.com/do     [ <=>                ]  79.37K  --.-KB/s    in 0.002s
#
# 2025-04-16 19:13:53 (42.7 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/components/placeholders/index.html’ saved [81272]
#
# --2025-04-16 19:13:53--  https://getbootstrap.com/docs/5.2/components/progress/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/components/progress/index.html’
#
# getbootstrap.com/do     [ <=>                ] 102.07K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:54 (237 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/components/progress/index.html’ saved [104517]
#
# --2025-04-16 19:13:54--  https://getbootstrap.com/docs/5.2/components/spinners/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/components/spinners/index.html’
#
# getbootstrap.com/do     [ <=>                ] 110.39K  --.-KB/s    in 0.002s
#
# 2025-04-16 19:13:54 (68.3 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/components/spinners/index.html’ saved [113036]
#
# --2025-04-16 19:13:54--  https://getbootstrap.com/docs/5.2/helpers/clearfix/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/helpers/clearfix/index.html’
#
# getbootstrap.com/do     [ <=>                ]  58.20K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:54 (259 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/helpers/clearfix/index.html’ saved [59592]
#
# --2025-04-16 19:13:54--  https://getbootstrap.com/docs/5.2/helpers/color-background/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/helpers/color-background/index.html’
#
# getbootstrap.com/do     [ <=>                ]  65.75K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:54 (114 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/helpers/color-background/index.html’ saved [67324]
#
# --2025-04-16 19:13:54--  https://getbootstrap.com/docs/5.2/helpers/colored-links/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/helpers/colored-links/index.html’
#
# getbootstrap.com/do     [ <=>                ]  58.22K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:54 (204 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/helpers/colored-links/index.html’ saved [59617]
#
# --2025-04-16 19:13:54--  https://getbootstrap.com/docs/5.2/helpers/position/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/helpers/position/index.html’
#
# getbootstrap.com/do     [ <=>                ]  61.81K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:54 (105 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/helpers/position/index.html’ saved [63294]
#
# --2025-04-16 19:13:54--  https://getbootstrap.com/docs/5.2/helpers/ratio/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/helpers/ratio/index.html’
#
# getbootstrap.com/do     [ <=>                ]  68.10K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:54 (65.9 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/helpers/ratio/index.html’ saved [69733]
#
# --2025-04-16 19:13:54--  https://getbootstrap.com/docs/5.2/helpers/stacks/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/helpers/stacks/index.html’
#
# getbootstrap.com/do     [ <=>                ]  73.04K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:55 (306 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/helpers/stacks/index.html’ saved [74798]
#
# --2025-04-16 19:13:55--  https://getbootstrap.com/docs/5.2/helpers/stretched-link/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/helpers/stretched-link/index.html’
#
# getbootstrap.com/do     [ <=>                ]  73.51K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:55 (212 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/helpers/stretched-link/index.html’ saved [75273]
#
# --2025-04-16 19:13:55--  https://getbootstrap.com/docs/5.2/helpers/text-truncation/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/helpers/text-truncation/index.html’
#
# getbootstrap.com/do     [ <=>                ]  56.52K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:55 (52.1 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/helpers/text-truncation/index.html’ saved [57872]
#
# --2025-04-16 19:13:55--  https://getbootstrap.com/docs/5.2/helpers/vertical-rule/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/helpers/vertical-rule/index.html’
#
# getbootstrap.com/do     [ <=>                ]  60.86K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:55 (334 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/helpers/vertical-rule/index.html’ saved [62316]
#
# --2025-04-16 19:13:55--  https://getbootstrap.com/docs/5.2/helpers/visually-hidden/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/helpers/visually-hidden/index.html’
#
# getbootstrap.com/do     [ <=>                ]  57.73K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:55 (118 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/helpers/visually-hidden/index.html’ saved [59115]
#
# --2025-04-16 19:13:55--  https://getbootstrap.com/docs/5.2/utilities/background/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/utilities/background/index.html’
#
# getbootstrap.com/do     [ <=>                ]  96.04K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:55 (136 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/utilities/background/index.html’ saved [98348]
#
# --2025-04-16 19:13:55--  https://getbootstrap.com/docs/5.2/utilities/borders/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/utilities/borders/index.html’
#
# getbootstrap.com/do     [ <=>                ] 125.93K  --.-KB/s    in 0.007s
#
# 2025-04-16 19:13:55 (16.5 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/utilities/borders/index.html’ saved [128955]
#
# --2025-04-16 19:13:55--  https://getbootstrap.com/docs/5.2/utilities/display/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/utilities/display/index.html’
#
# getbootstrap.com/do     [ <=>                ]  68.99K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:56 (138 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/utilities/display/index.html’ saved [70647]
#
# --2025-04-16 19:13:56--  https://getbootstrap.com/docs/5.2/utilities/flex/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/utilities/flex/index.html’
#
# getbootstrap.com/do     [ <=>                ] 140.79K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:56 (142 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/utilities/flex/index.html’ saved [144165]
#
# --2025-04-16 19:13:56--  https://getbootstrap.com/docs/5.2/utilities/float/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/utilities/float/index.html’
#
# getbootstrap.com/do     [ <=>                ]  62.78K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:56 (192 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/utilities/float/index.html’ saved [64288]
#
# --2025-04-16 19:13:56--  https://getbootstrap.com/docs/5.2/utilities/interactions/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/utilities/interactions/index.html’
#
# getbootstrap.com/do     [ <=>                ]  63.22K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:56 (212 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/utilities/interactions/index.html’ saved [64735]
#
# --2025-04-16 19:13:56--  https://getbootstrap.com/docs/5.2/utilities/opacity/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/utilities/opacity/index.html’
#
# getbootstrap.com/do     [ <=>                ]  57.26K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:56 (261 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/utilities/opacity/index.html’ saved [58638]
#
# --2025-04-16 19:13:56--  https://getbootstrap.com/docs/5.2/utilities/overflow/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/utilities/overflow/index.html’
#
# getbootstrap.com/do     [ <=>                ]  57.47K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:57 (202 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/utilities/overflow/index.html’ saved [58848]
#
# --2025-04-16 19:13:57--  https://getbootstrap.com/docs/5.2/utilities/spacing/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/utilities/spacing/index.html’
#
# getbootstrap.com/do     [ <=>                ]  90.47K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:57 (285 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/utilities/spacing/index.html’ saved [92644]
#
# --2025-04-16 19:13:57--  https://getbootstrap.com/docs/5.2/utilities/text/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/utilities/text/index.html’
#
# getbootstrap.com/do     [ <=>                ] 105.48K  --.-KB/s    in 0.001s
#
# 2025-04-16 19:13:57 (88.6 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/utilities/text/index.html’ saved [108016]
#
# --2025-04-16 19:13:57--  https://getbootstrap.com/docs/5.2/utilities/vertical-align/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/5.2/utilities/vertical-align/index.html’
#
# getbootstrap.com/do     [ <=>                ]  62.82K  --.-KB/s    in 0s
#
# 2025-04-16 19:13:57 (294 MB/s) - ‘rtdocs/getbootstrap.com/docs/5.2/utilities/vertical-align/index.html’ saved [64325]
#
# --2025-04-16 19:13:57--  https://getbootstrap.com/docs/5.2/utilities/visibility/
# ...
#
# getbootstrap.com/2.     [ <=>                ]  13.90K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:49 (250 MB/s) - ‘rtdocs/getbootstrap.com/2.0.0/upgrading.html’ saved [14234]
#
# --2025-04-16 19:14:49--  https://getbootstrap.com/1.4.0/javascript.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/1.4.0/javascript.html’
#
# getbootstrap.com/1.     [ <=>                ]  37.46K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:49 (319 MB/s) - ‘rtdocs/getbootstrap.com/1.4.0/javascript.html’ saved [38355]
#
# --2025-04-16 19:14:49--  https://getbootstrap.com/1.4.0/examples/hero.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/1.4.0/examples/hero.html’
#
# getbootstrap.com/1.     [ <=>                ]   3.19K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:49 (635 MB/s) - ‘rtdocs/getbootstrap.com/1.4.0/examples/hero.html’ saved [3267]
#
# --2025-04-16 19:14:49--  https://getbootstrap.com/1.4.0/examples/fluid.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/1.4.0/examples/fluid.html’
#
# getbootstrap.com/1.     [ <=>                ]   5.39K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:49 (1.10 GB/s) - ‘rtdocs/getbootstrap.com/1.4.0/examples/fluid.html’ saved [5518]
#
# --2025-04-16 19:14:49--  https://getbootstrap.com/1.4.0/examples/container-app.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/1.4.0/examples/container-app.html’
#
# getbootstrap.com/1.     [ <=>                ]   3.67K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:49 (688 MB/s) - ‘rtdocs/getbootstrap.com/1.4.0/examples/container-app.html’ saved [3756]
#
# --2025-04-16 19:14:49--  https://getbootstrap.com/1.3.0/javascript.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/1.3.0/javascript.html’
#
# getbootstrap.com/1.     [ <=>                ]  30.86K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:50 (183 MB/s) - ‘rtdocs/getbootstrap.com/1.3.0/javascript.html’ saved [31603]
#
# --2025-04-16 19:14:50--  https://getbootstrap.com/1.3.0/examples/hero.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/1.3.0/examples/hero.html’
#
# getbootstrap.com/1.     [ <=>                ]   3.16K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:50 (554 MB/s) - ‘rtdocs/getbootstrap.com/1.3.0/examples/hero.html’ saved [3240]
#
# --2025-04-16 19:14:50--  https://getbootstrap.com/1.3.0/examples/fluid.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/1.3.0/examples/fluid.html’
#
# getbootstrap.com/1.     [ <=>                ]   5.39K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:50 (1.03 GB/s) - ‘rtdocs/getbootstrap.com/1.3.0/examples/fluid.html’ saved [5522]
#
# --2025-04-16 19:14:50--  https://getbootstrap.com/1.3.0/examples/container-app.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/1.3.0/examples/container-app.html’
#
# getbootstrap.com/1.     [ <=>                ]   3.66K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:50 (876 MB/s) - ‘rtdocs/getbootstrap.com/1.3.0/examples/container-app.html’ saved [3743]
#
# --2025-04-16 19:14:50--  https://getbootstrap.com/docs/5.1/getting-started/vite/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-04-16 19:14:50 ERROR 404: Not Found.
#
# --2025-04-16 19:14:50--  https://getbootstrap.com/docs/5.0/getting-started/vite/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2025-04-16 19:14:50 ERROR 404: Not Found.
#
# --2025-04-16 19:14:50--  https://getbootstrap.com/docs/4.0/examples/album/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/album/index.html’
#
# getbootstrap.com/do     [ <=>                ]  12.52K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:50 (283 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/album/index.html’ saved [12817]
#
# --2025-04-16 19:14:50--  https://getbootstrap.com/docs/4.0/examples/pricing/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/pricing/index.html’
#
# getbootstrap.com/do     [ <=>                ]   6.10K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:51 (1.05 GB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/pricing/index.html’ saved [6244]
#
# --2025-04-16 19:14:51--  https://getbootstrap.com/docs/4.0/examples/checkout/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/checkout/index.html’
#
# getbootstrap.com/do     [ <=>                ]  11.74K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:51 (275 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/checkout/index.html’ saved [12018]
#
# --2025-04-16 19:14:51--  https://getbootstrap.com/docs/4.0/examples/product/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/product/index.html’
#
# getbootstrap.com/do     [ <=>                ]   9.14K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:51 (211 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/product/index.html’ saved [9361]
#
# --2025-04-16 19:14:51--  https://getbootstrap.com/docs/4.0/examples/cover/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/cover/index.html’
#
# getbootstrap.com/do     [ <=>                ]   2.36K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:51 (536 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/cover/index.html’ saved [2419]
#
# --2025-04-16 19:14:51--  https://getbootstrap.com/docs/4.0/examples/carousel/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/carousel/index.html’
#
# getbootstrap.com/do     [ <=>                ]  10.00K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:51 (216 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/carousel/index.html’ saved [10235]
#
# --2025-04-16 19:14:51--  https://getbootstrap.com/docs/4.0/examples/blog/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/blog/index.html’
#
# getbootstrap.com/do     [ <=>                ]  12.54K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:51 (277 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/blog/index.html’ saved [12846]
#
# --2025-04-16 19:14:51--  https://getbootstrap.com/docs/4.0/examples/dashboard/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/dashboard/index.html’
#
# getbootstrap.com/do     [ <=>                ]   9.99K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:51 (195 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/dashboard/index.html’ saved [10230]
#
# --2025-04-16 19:14:51--  https://getbootstrap.com/docs/4.0/examples/sign-in/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/sign-in/index.html’
#
# getbootstrap.com/do     [ <=>                ]   1.53K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:52 (308 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/sign-in/index.html’ saved [1570]
#
# --2025-04-16 19:14:52--  https://getbootstrap.com/docs/4.0/examples/sticky-footer/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/sticky-footer/index.html’
#
# getbootstrap.com/do     [ <=>                ]   1.20K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:52 (305 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/sticky-footer/index.html’ saved [1228]
#
# --2025-04-16 19:14:52--  https://getbootstrap.com/docs/4.0/examples/sticky-footer-navbar/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/sticky-footer-navbar/index.html’
#
# getbootstrap.com/do     [ <=>                ]   3.12K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:52 (660 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/sticky-footer-navbar/index.html’ saved [3199]
#
# --2025-04-16 19:14:52--  https://getbootstrap.com/docs/4.0/examples/starter-template/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/starter-template/index.html’
#
# getbootstrap.com/do     [ <=>                ]   3.21K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:52 (737 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/starter-template/index.html’ saved [3286]
#
# --2025-04-16 19:14:52--  https://getbootstrap.com/docs/4.0/examples/grid/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/grid/index.html’
#
# getbootstrap.com/do     [ <=>                ]   5.24K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:52 (1.14 GB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/grid/index.html’ saved [5367]
#
# --2025-04-16 19:14:52--  https://getbootstrap.com/docs/4.0/examples/jumbotron/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/jumbotron/index.html’
#
# getbootstrap.com/do     [ <=>                ]   4.95K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:52 (890 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/jumbotron/index.html’ saved [5072]
#
# --2025-04-16 19:14:52--  https://getbootstrap.com/docs/4.0/examples/navbars/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/navbars/index.html’
#
# getbootstrap.com/do     [ <=>                ]  16.31K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:52 (215 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/navbars/index.html’ saved [16700]
#
# --2025-04-16 19:14:52--  https://getbootstrap.com/docs/4.0/examples/navbar-static/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/navbar-static/index.html’
#
# getbootstrap.com/do     [ <=>                ]   2.80K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:52 (470 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/navbar-static/index.html’ saved [2870]
#
# --2025-04-16 19:14:52--  https://getbootstrap.com/docs/4.0/examples/navbar-fixed/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/navbar-fixed/index.html’
#
# getbootstrap.com/do     [ <=>                ]   2.80K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:53 (517 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/navbar-fixed/index.html’ saved [2863]
#
# --2025-04-16 19:14:53--  https://getbootstrap.com/docs/4.0/examples/navbar-bottom/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/navbar-bottom/index.html’
#
# getbootstrap.com/do     [ <=>                ]   2.87K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:53 (432 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/navbar-bottom/index.html’ saved [2940]
#
# --2025-04-16 19:14:53--  https://getbootstrap.com/docs/4.0/examples/floating-labels/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/floating-labels/index.html’
#
# getbootstrap.com/do     [ <=>                ]   1.89K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:53 (342 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/floating-labels/index.html’ saved [1940]
#
# --2025-04-16 19:14:53--  https://getbootstrap.com/docs/4.0/examples/offcanvas/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/examples/offcanvas/index.html’
#
# getbootstrap.com/do     [ <=>                ]   7.60K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:53 (1.12 GB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/examples/offcanvas/index.html’ saved [7783]
#
# --2025-04-16 19:14:53--  https://getbootstrap.com/docs/4.0/browser-bugs/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/browser-bugs/index.html’
#
# getbootstrap.com/do     [ <=>                ]  44.45K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:53 (284 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/browser-bugs/index.html’ saved [45521]
#
# --2025-04-16 19:14:53--  https://getbootstrap.com/docs/4.0/getting-started/options/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/getting-started/options/index.html’
#
# getbootstrap.com/do     [ <=>                ]     577  --.-KB/s    in 0s
#
# 2025-04-16 19:14:53 (150 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/getting-started/options/index.html’ saved [577]
#
# --2025-04-16 19:14:53--  https://getbootstrap.com/docs/4.0/utilities/
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/docs/4.0/utilities/index.html’
#
# getbootstrap.com/do     [ <=>                ]     553  --.-KB/s    in 0s
#
# 2025-04-16 19:14:53 (155 MB/s) - ‘rtdocs/getbootstrap.com/docs/4.0/utilities/index.html’ saved [553]
#
# --2025-04-16 19:14:53--  https://getbootstrap.com/2.3.2/examples/sticky-footer-navbar.html
# Reusing existing connection to getbootstrap.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘rtdocs/getbootstrap.com/2.3.2/examples/sticky-footer-navbar.html’
#
# getbootstrap.com/2.     [ <=>                ]   5.65K  --.-KB/s    in 0s
#
# 2025-04-16 19:14:54 (347 MB/s) - ‘rtdocs/getbootstrap.com/2.3.2/examples/sticky-footer-navbar.html’ saved [5787]
#
# FINISHED --2025-04-16 19:14:54--
# Total wall clock time: 2m 13s
# Downloaded: 938 files, 47M in 0.5s (98.6 MB/s)

# %%
from langchain.document_loaders import ReadTheDocsLoader

loader = ReadTheDocsLoader('rtdocs')
docs = loader.load()
len(docs)
# Out:
# 925

# %%
docs[315]
# Out:
# Document(metadata={'source': 'rtdocs/getbootstrap.com/docs/5.3/forms/validation/index.html'}, page_content='')

# %%
print(docs[5].page_content)
